# %%
import csv
import numpy as np
import sklearn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import seaborn as sb
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from keras.datasets import reuters
from sklearn.svm import LinearSVC, SVC
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
#get data from Keras 
max_features = 1000
(x_train, y_train), (x_test, y_test) = reuters.load_data(num_words=max_features)

#decode 
word_index = reuters.get_word_index()
revers_word_indx = dict([(value, key) for (key, value) in word_index.items()])

x_train = [
    ' '.join(revers_word_indx[i] for i in x_train[i] if i < len(revers_word_indx))for i in range(x_train.shape[0])
]

x_test = [
    ' '.join(revers_word_indx[i] for i in x_test[i] if i < len(revers_word_indx))for i in range(x_test.shape[0])
]

# %%
#model 
model = Pipeline([
    ('tfidf', TfidfVectorizer(ngram_range=(1,2), stop_words='english', sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1')),
    ('svc', LinearSVC())
])

history = model.fit(x_train, y_train)
print("done")
# Out:
# done

# %%
#Model Accuracy
y_pred = model.predict(x_test)
print(classification_report(y_pred, y_test))
print((y_pred == y_test).mean())
# Out:
#              precision    recall  f1-score   support
#
#           0       0.67      0.89      0.76         9
#           1       0.77      0.70      0.74       115
#           2       0.50      0.71      0.59        14
#           3       0.94      0.92      0.93       831
#           4       0.88      0.80      0.84       519
#           5       0.00      0.00      0.00         0
#           6       0.93      0.87      0.90        15
#           7       0.67      1.00      0.80         2
#           8       0.71      0.69      0.70        39
#           9       0.84      0.78      0.81        27
#          10       0.60      0.62      0.61        29
#          11       0.83      0.63      0.72       110
#          12       0.54      0.78      0.64         9
#          13       0.57      0.47      0.51        45
#          14       0.50      0.50      0.50         2
#          15       0.11      0.50      0.18         2
#          16       0.71      0.68      0.69       103
#          17       0.50      0.86      0.63         7
#          18       0.60      0.80      0.69        15
#          19       0.74      0.73      0.73       134
#          20       0.59      0.69      0.64        59
#          21       0.85      0.66      0.74        35
#          22       0.00      0.00      0.00         0
#          23       0.17      0.29      0.21         7
#          24       0.42      0.57      0.48        14
#          25       0.84      0.90      0.87        29
#          26       0.50      0.67      0.57         6
#          27       0.25      0.50      0.33         2
#          28       0.30      0.43      0.35         7
#          29       0.50      0.50      0.50         4
#          30       0.50      1.00      0.67         6
#          31       0.23      0.75      0.35         4
#          32       0.50      1.00      0.67         5
#          33       0.80      1.00      0.89         4
#          34       0.57      0.80      0.67         5
#          35       0.33      1.00      0.50         2
#          36       0.36      0.50      0.42         8
#          37       0.50      1.00      0.67         1
#          38       0.00      0.00      0.00         0
#          39       0.40      0.67      0.50         3
#          40       0.20      0.67      0.31         3
#          41       0.12      0.50      0.20         2
#          42       0.33      1.00      0.50         1
#          43       0.83      0.71      0.77         7
#          44       0.80      1.00      0.89         4
#          45       1.00      1.00      1.00         1
#
# avg / total       0.83      0.80      0.81      2246
#
# 0.8023152270703473
# C:\Users\yongj\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
#confusioin matrix
conf_mat = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(15,15))
sb.heatmap(conf_mat, annot=True, fmt='d')
plt.ylabel('Actual Class')
plt.xlabel('Predicted Class')
plt.show()
