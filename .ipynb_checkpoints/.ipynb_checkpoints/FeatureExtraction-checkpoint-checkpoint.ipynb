# %%
import csv
import numpy as np
import sklearn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import chi2
from sklearn.manifold import TSNE

# %%
data = pd.read_csv('data.csv')
print("readed")
# Out:
# readed

# %%
#convert each label into numerical representation
data['label_id'] = data['label'].factorize()[0]

label_id_data = data[['label', 'label_id']].drop_duplicates().sort_values('label_id')
label_to_id = dict(label_id_data.values)
id_to_label = dict(label_id_data[['label_id', 'label']].values)

# %%
#Fine most correlated terms in each document by term frequency-inverse document frequency
tf_idf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 3), stop_words='english')

features = tf_idf.fit_transform(data.content).toarray()
labels = data.label_id
features.shape
# Out:
# (13294, 89740)

# %%
#The output terms are the most correlated with each of the categories in unigram, bigram, and trigram:
N = 3
for label, label_id in label_to_id.items():
  features_chi2 = chi2(features, labels == label_id)
  indices = np.argsort(features_chi2[0])
  feature_names = np.array(tf_idf.get_feature_names())[indices]

  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
  trigrams = [v for v in feature_names if len(v.split(' ')) == 3]

  print("# '{}':".format(label))
  print("  . Most correlated unigrams:\n       . {}".format('\n       . '.join(unigrams[-N:])))
  print("  . Most correlated bigrams:\n       . {}".format('\n       . '.join(bigrams[-N:])))
  print("  . Most correlated trigrams:\n       . {}".format('\n       . '.join(trigrams[-N:])))
# Out:
# # 'acq':
#   . Most correlated unigrams:
#        . tonnes
#        . cyclops
#        . twa
#   . Most correlated bigrams:
#        . harper row
#        . waste management
#        . 000 tonnes
#   . Most correlated trigrams:
#        . trans world airlines
#        . entered talks acquisition
#        . talks acquisition parties
# # 'alum':
#   . Most correlated unigrams:
#        . spirits
#        . textile
#        . datron
#   . Most correlated bigrams:
#        . 545 mln
#        . trump interstate
#        . american brands
#   . Most correlated trigrams:
#        . dlrs american brands
#        . trump interstate properties
#        . 545 mln dlrs
# # 'barley':
#   . Most correlated unigrams:
#        . spirits
#        . textile
#        . datron
#   . Most correlated bigrams:
#        . 545 mln
#        . trump interstate
#        . american brands
#   . Most correlated trigrams:
#        . dlrs american brands
#        . trump interstate properties
#        . 545 mln dlrs
# # 'bop':
#   . Most correlated unigrams:
#        . beverages
#        . faygo
#        . clevite
#   . Most correlated bigrams:
#        . faygo beverages
#        . clevite industries
#        . national beverage
#   . Most correlated trigrams:
#        . hospital corp says
#        . says received 47
#        . share offer investor
# # 'carcass':
#   . Most correlated unigrams:
#        . waccamaw
#        . purolator
#        . lbo
#   . Most correlated bigrams:
#        . agreement purolator
#        . purolator courier
#        . hutton lbo
#   . Most correlated trigrams:
#        . hutton lbo said
#        . lbo said tender
#        . merger agreement purolator
# # 'castor-oil':
#   . Most correlated unigrams:
#        . komatsu
#        . sumitomo
#        . atlas
#   . Most correlated bigrams:
#        . securities business
#        . komatsu said
#        . atlas said
#   . Most correlated trigrams:
#        . said development pre
#        . atlas statement said
#        . 976 38 mln
# # 'cocoa':
#   . Most correlated unigrams:
#        . purolator
#        . lvi
#        . lbo
#   . Most correlated bigrams:
#        . data access
#        . purolator courier
#        . hutton lbo
#   . Most correlated trigrams:
#        . hutton lbo said
#        . lbo said tender
#        . merger agreement purolator
# # 'coconut':
#   . Most correlated unigrams:
#        . nl
#        . monier
#        . whim
#   . Most correlated bigrams:
#        . standard chartered
#        . bell group
#        . whim creek
#   . Most correlated trigrams:
#        . headquarters confirmed brokers
#        . director standard available
#        . bell chairman robert
# # 'coconut-oil':
#   . Most correlated unigrams:
#        . forrest
#        . monier
#        . whim
#   . Most correlated bigrams:
#        . bell group
#        . whim creek
#        . nippon steel
#   . Most correlated trigrams:
#        . acquiring shares sentence
#        . brokers warburg securities
#        . quoted nippon steel
# # 'coffee':
#   . Most correlated unigrams:
#        . cadillac
#        . ecusta
#        . glatfelter
#   . Most correlated bigrams:
#        . blue arrow
#        . says received
#        . cadillac fairview
#   . Most correlated trigrams:
#        . fairview says received
#        . cadillac fairview says
#        . ecusta corp 149
# # 'copper':
#   . Most correlated unigrams:
#        . lbo
#        . acquisittion
#        . datron
#   . Most correlated bigrams:
#        . lbo says
#        . 13 50
#        . american brands
#   . Most correlated trigrams:
#        . unit terminates merger
#        . hutton lbo says
#        . lbo says unit
# # 'copra-cake':
#   . Most correlated unigrams:
#        . forrest
#        . cra
#        . whim
#   . Most correlated bigrams:
#        . atlas said
#        . forrest gold
#        . whim creek
#   . Most correlated trigrams:
#        . price yesterday whim
#        . gold owns mines
#        . reported yesterday cra
# # 'corn':
#   . Most correlated unigrams:
#        . lane
#        . transcanada
#        . interco
#   . Most correlated bigrams:
#        . eddie dlrs
#        . boeing acquire
#        . interco said
#   . Most correlated trigrams:
#        . crazy eddie dlrs
#        . standard oil says
#        . 37 dlrs share
# # 'cotton':
#   . Most correlated unigrams:
#        . spirits
#        . textile
#        . datron
#   . Most correlated bigrams:
#        . 545 mln
#        . trump interstate
#        . american brands
#   . Most correlated trigrams:
#        . sell spirits unit
#        . trump interstate properties
#        . 545 mln dlrs
# # 'cotton-oil':
#   . Most correlated unigrams:
#        . forrest
#        . cra
#        . whim
#   . Most correlated bigrams:
#        . atlas said
#        . forrest gold
#        . whim creek
#   . Most correlated trigrams:
#        . price yesterday whim
#        . gold owns mines
#        . reported yesterday cra
# # 'cpi':
#   . Most correlated unigrams:
#        . beverages
#        . faygo
#        . clevite
#   . Most correlated bigrams:
#        . faygo beverages
#        . clevite industries
#        . national beverage
#   . Most correlated trigrams:
#        . national beverage corp
#        . lt national beverage
#        . 13 50 dlrs
# # 'cpu':
#   . Most correlated unigrams:
#        . nl
#        . forrest
#        . whim
#   . Most correlated bigrams:
#        . anheuser busch
#        . forrest gold
#        . whim creek
#   . Most correlated trigrams:
#        . craa lt forrest
#        . lt craa lt
#        . shares told reuters
# # 'crude':
#   . Most correlated unigrams:
#        . rte
#        . oil
#        . tonnes
#   . Most correlated bigrams:
#        . new generation
#        . wpp group
#        . 000 tonnes
#   . Most correlated trigrams:
#        . martin processing said
#        . pct stake digiorgio
#        . terminates takeover talks
# # 'dfl':
#   . Most correlated unigrams:
#        . forrest
#        . cra
#        . whim
#   . Most correlated bigrams:
#        . atlas said
#        . forrest gold
#        . whim creek
#   . Most correlated trigrams:
#        . price yesterday whim
#        . gold owns mines
#        . reported yesterday cra
# # 'dlr':
#   . Most correlated unigrams:
#        . swift
#        . ranchman
#        . gander
#   . Most correlated bigrams:
#        . dakota pork
#        . gander mountain
#        . western ranchman
#   . Most correlated trigrams:
#        . 20 10 dlrs
#        . south dakota pork
#        . dakota pork plant
# # 'dmk':
#   . Most correlated unigrams:
#        . bell
#        . auxton
#        . conrac
#   . Most correlated bigrams:
#        . entered talks
#        . acquisition parties
#        . conrac corp
#   . Most correlated trigrams:
#        . said entered talks
#        . talks acquisition parties
#        . entered talks acquisition
# # 'earn':
#   . Most correlated unigrams:
#        . corn
#        . oil
#        . tonnes
#   . Most correlated bigrams:
#        . current account
#        . crude oil
#        . 000 tonnes
#   . Most correlated trigrams:
#        . trade sources said
#        . 000 tonnes corn
#        . current account deficit
# # 'fuel':
#   . Most correlated unigrams:
#        . wedgestone
#        . paxar
#        . conrac
#   . Most correlated bigrams:
#        . entered talks
#        . acquisition parties
#        . conrac corp
#   . Most correlated trigrams:
#        . said entered talks
#        . talks acquisition parties
#        . entered talks acquisition
# # 'gas':
#   . Most correlated unigrams:
#        . spirits
#        . textile
#        . datron
#   . Most correlated bigrams:
#        . 545 mln
#        . trump interstate
#        . american brands
#   . Most correlated trigrams:
#        . dlrs american brands
#        . trump interstate properties
#        . 545 mln dlrs
# # 'gnp':
#   . Most correlated unigrams:
#        . cadillac
#        . ecusta
#        . glatfelter
#   . Most correlated bigrams:
#        . blue arrow
#        . says received
#        . cadillac fairview
#   . Most correlated trigrams:
#        . fairview says received
#        . cadillac fairview says
#        . ecusta corp 149
# # 'gold':
#   . Most correlated unigrams:
#        . clevite
#        . cadillac
#        . fairview
#   . Most correlated bigrams:
#        . fairview says
#        . says received
#        . cadillac fairview
#   . Most correlated trigrams:
#        . received acquisition proposals
#        . cadillac fairview says
#        . fairview says received
# # 'grain':
#   . Most correlated unigrams:
#        . rte
#        . oil
#        . tonnes
#   . Most correlated bigrams:
#        . new generation
#        . wpp group
#        . 000 tonnes
#   . Most correlated trigrams:
#        . martin processing said
#        . pct stake digiorgio
#        . terminates takeover talks
# # 'groundnut':
#   . Most correlated unigrams:
#        . miguel
#        . bell
#        . auxton
#   . Most correlated bigrams:
#        . nippon steel
#        . san miguel
#        . cincinnati bell
#   . Most correlated trigrams:
#        . csn starts auxton
#        . quoted nippon steel
#        . san miguel corp
# # 'groundnut-oil':
#   . Most correlated unigrams:
#        . komatsu
#        . sumitomo
#        . atlas
#   . Most correlated bigrams:
#        . securities business
#        . komatsu said
#        . atlas said
#   . Most correlated trigrams:
#        . said development pre
#        . atlas statement said
#        . 976 38 mln
# # 'heat':
#   . Most correlated unigrams:
#        . wedgestone
#        . paxar
#        . conrac
#   . Most correlated bigrams:
#        . entered talks
#        . acquisition parties
#        . conrac corp
#   . Most correlated trigrams:
#        . said entered talks
#        . entered talks acquisition
#        . talks acquisition parties
# # 'hog':
#   . Most correlated unigrams:
#        . wedgestone
#        . paxar
#        . conrac
#   . Most correlated bigrams:
#        . entered talks
#        . acquisition parties
#        . conrac corp
#   . Most correlated trigrams:
#        . said entered talks
#        . talks acquisition parties
#        . entered talks acquisition
# # 'housing':
#   . Most correlated unigrams:
#        . wedgestone
#        . paxar
#        . conrac
#   . Most correlated bigrams:
#        . entered talks
#        . acquisition parties
#        . conrac corp
#   . Most correlated trigrams:
#        . said entered talks
#        . entered talks acquisition
#        . talks acquisition parties
# # 'income':
#   . Most correlated unigrams:
#        . bashaw
#        . paxar
#        . conrac
#   . Most correlated bigrams:
#        . entered talks
#        . acquisition parties
#        . conrac corp
#   . Most correlated trigrams:
#        . said entered talks
#        . talks acquisition parties
#        . entered talks acquisition
# # 'instal-debt':
#   . Most correlated unigrams:
#        . nl
#        . monier
#        . whim
#   . Most correlated bigrams:
#        . standard chartered
#        . bell group
#        . whim creek
#   . Most correlated trigrams:
#        . headquarters confirmed brokers
#        . director standard available
#        . bell chairman robert
# # 'interest':
#   . Most correlated unigrams:
#        . electrospace
#        . tonnes
#        . gillette
#   . Most correlated bigrams:
#        . electrospace systems
#        . continental materials
#        . 000 tonnes
#   . Most correlated trigrams:
#        . sell rko pictures
#        . gencorp said agreement
#        . agreement sell rko
# # 'ipi':
#   . Most correlated unigrams:
#        . spirits
#        . textile
#        . datron
#   . Most correlated bigrams:
#        . 545 mln
#        . trump interstate
#        . american brands
#   . Most correlated trigrams:
#        . sell spirits unit
#        . trump interstate properties
#        . 545 mln dlrs
# # 'iron-steel':
#   . Most correlated unigrams:
#        . spirits
#        . textile
#        . datron
#   . Most correlated bigrams:
#        . 545 mln
#        . trump interstate
#        . american brands
#   . Most correlated trigrams:
#        . dlrs american brands
#        . trump interstate properties
#        . 545 mln dlrs
# # 'jet':
#   . Most correlated unigrams:
#        . nl
#        . monier
#        . whim
#   . Most correlated bigrams:
#        . anheuser busch
#        . forrest gold
#        . whim creek
#   . Most correlated trigrams:
#        . statement reported forrest
#        . pct consortium lt
#        . shares told reuters
# # 'jobs':
#   . Most correlated unigrams:
#        . waccamaw
#        . purolator
#        . lbo
#   . Most correlated bigrams:
#        . agreement purolator
#        . purolator courier
#        . hutton lbo
#   . Most correlated trigrams:
#        . hutton lbo said
#        . lbo said tender
#        . merger agreement purolator
# # 'l-cattle':
#   . Most correlated unigrams:
#        . whim
#        . sequestered
#        . miguel
#   . Most correlated bigrams:
#        . sequestered shares
#        . nippon steel
#        . san miguel
#   . Most correlated trigrams:
#        . standard bell chairman
#        . quoted nippon steel
#        . san miguel corp
# # 'lead':
#   . Most correlated unigrams:
#        . conrac
#        . rumor
#        . madeira
#   . Most correlated bigrams:
#        . properties talks
#        . dominion textile
#        . acquire alexanders
#   . Most correlated trigrams:
#        . talks acquire alexanders
#        . interstate properties talks
#        . properties talks acquire
# # 'lei':
#   . Most correlated unigrams:
#        . auxton
#        . paxar
#        . conrac
#   . Most correlated bigrams:
#        . entered talks
#        . acquisition parties
#        . conrac corp
#   . Most correlated trigrams:
#        . said entered talks
#        . entered talks acquisition
#        . talks acquisition parties
# # 'lin-oil':
#   . Most correlated unigrams:
#        . komatsu
#        . sumitomo
#        . atlas
#   . Most correlated bigrams:
#        . securities business
#        . komatsu said
#        . atlas said
#   . Most correlated trigrams:
#        . said development pre
#        . atlas statement said
#        . 976 38 mln
# # 'livestock':
#   . Most correlated unigrams:
#        . beverages
#        . faygo
#        . clevite
#   . Most correlated bigrams:
#        . faygo beverages
#        . clevite industries
#        . national beverage
#   . Most correlated trigrams:
#        . beverage acquire faygo
#        . beverages undisclosed cash
#        . 13 50 dlrs
# # 'lumber':
#   . Most correlated unigrams:
#        . bashaw
#        . paxar
#        . conrac
#   . Most correlated bigrams:
#        . entered talks
#        . acquisition parties
#        . conrac corp
#   . Most correlated trigrams:
#        . said entered talks
#        . talks acquisition parties
#        . entered talks acquisition
# # 'meal-feed':
#   . Most correlated unigrams:
#        . alexanders
#        . textile
#        . datron
#   . Most correlated bigrams:
#        . interstate properties
#        . sell spirits
#        . trump interstate
#   . Most correlated trigrams:
#        . sell spirits unit
#        . dlrs american brands
#        . trump interstate properties
# # 'money-fx':
#   . Most correlated unigrams:
#        . telex
#        . corby
#        . ccr
#   . Most correlated bigrams:
#        . corby distilleries
#        . ccr video
#        . media general
#   . Most correlated trigrams:
#        . intercep investment corp
#        . share reason given
#        . dlrs share reason
# # 'money-supply':
#   . Most correlated unigrams:
#        . swift
#        . ranchman
#        . gander
#   . Most correlated bigrams:
#        . plant swift
#        . gander mountain
#        . western ranchman
#   . Most correlated trigrams:
#        . 20 10 dlrs
#        . south dakota pork
#        . dakota pork plant
# # 'naphtha':
#   . Most correlated unigrams:
#        . nl
#        . monier
#        . whim
#   . Most correlated bigrams:
#        . standard chartered
#        . bell group
#        . whim creek
#   . Most correlated trigrams:
#        . headquarters confirmed brokers
#        . director standard available
#        . bell chairman robert
# # 'nat-gas':
#   . Most correlated unigrams:
#        . beverages
#        . faygo
#        . clevite
#   . Most correlated bigrams:
#        . faygo beverages
#        . clevite industries
#        . national beverage
#   . Most correlated trigrams:
#        . hospital corp says
#        . says received 47
#        . share offer investor
# # 'nickel':
#   . Most correlated unigrams:
#        . miguel
#        . bell
#        . auxton
#   . Most correlated bigrams:
#        . nippon steel
#        . san miguel
#        . cincinnati bell
#   . Most correlated trigrams:
#        . csn starts auxton
#        . quoted nippon steel
#        . san miguel corp
# # 'nkr':
#   . Most correlated unigrams:
#        . forrest
#        . cra
#        . whim
#   . Most correlated bigrams:
#        . atlas said
#        . forrest gold
#        . whim creek
#   . Most correlated trigrams:
#        . price yesterday whim
#        . gold owns mines
#        . reported yesterday cra
# # 'nzdlr':
#   . Most correlated unigrams:
#        . nl
#        . forrest
#        . whim
#   . Most correlated bigrams:
#        . anheuser busch
#        . forrest gold
#        . whim creek
#   . Most correlated trigrams:
#        . craa lt forrest
#        . lt craa lt
#        . shares told reuters
# # 'oat':
#   . Most correlated unigrams:
#        . bell
#        . auxton
#        . conrac
#   . Most correlated bigrams:
#        . entered talks
#        . acquisition parties
#        . conrac corp
#   . Most correlated trigrams:
#        . said entered talks
#        . talks acquisition parties
#        . entered talks acquisition
# # 'oilseed':
#   . Most correlated unigrams:
#        . ecusta
#        . glatfelter
#        . swift
#   . Most correlated bigrams:
#        . dakota pork
#        . pork plant
#        . south dakota
#   . Most correlated trigrams:
#        . 20 10 dlrs
#        . dakota pork plant
#        . south dakota pork
# # 'orange':
#   . Most correlated unigrams:
#        . conrac
#        . rumor
#        . madeira
#   . Most correlated bigrams:
#        . textile calls
#        . calls report
#        . dominion textile
#   . Most correlated trigrams:
#        . textile calls report
#        . report bid burlington
#        . calls report bid
# # 'palladium':
#   . Most correlated unigrams:
#        . forrest
#        . cra
#        . whim
#   . Most correlated bigrams:
#        . atlas said
#        . forrest gold
#        . whim creek
#   . Most correlated trigrams:
#        . price yesterday whim
#        . gold owns mines
#        . reported yesterday cra
# # 'palm-oil':
#   . Most correlated unigrams:
#        . alexanders
#        . textile
#        . datron
#   . Most correlated bigrams:
#        . datron common
#        . interstate properties
#        . trump interstate
#   . Most correlated trigrams:
#        . properties talks acquire
#        . interstate properties talks
#        . trump interstate properties
# # 'palmkernel':
#   . Most correlated unigrams:
#        . forrest
#        . cra
#        . whim
#   . Most correlated bigrams:
#        . atlas said
#        . forrest gold
#        . whim creek
#   . Most correlated trigrams:
#        . price yesterday whim
#        . gold owns mines
#        . reported yesterday cra
# # 'pet-chem':
#   . Most correlated unigrams:
#        . madeira
#        . interstate
#        . alexanders
#   . Most correlated bigrams:
#        . acquire alexanders
#        . interstate properties
#        . trump interstate
#   . Most correlated trigrams:
#        . interstate properties talks
#        . properties talks acquire
#        . trump interstate properties
# # 'platinum':
#   . Most correlated unigrams:
#        . bell
#        . auxton
#        . conrac
#   . Most correlated bigrams:
#        . entered talks
#        . acquisition parties
#        . conrac corp
#   . Most correlated trigrams:
#        . said entered talks
#        . talks acquisition parties
#        . entered talks acquisition
# # 'potato':
#   . Most correlated unigrams:
#        . nl
#        . monier
#        . whim
#   . Most correlated bigrams:
#        . standard chartered
#        . bell group
#        . whim creek
#   . Most correlated trigrams:
#        . headquarters confirmed brokers
#        . director standard available
#        . bell chairman robert
# # 'propane':
#   . Most correlated unigrams:
#        . nl
#        . monier
#        . whim
#   . Most correlated bigrams:
#        . standard chartered
#        . bell group
#        . whim creek
#   . Most correlated trigrams:
#        . headquarters confirmed brokers
#        . director standard available
#        . bell chairman robert
# # 'rand':
#   . Most correlated unigrams:
#        . forrest
#        . cra
#        . whim
#   . Most correlated bigrams:
#        . atlas said
#        . forrest gold
#        . whim creek
#   . Most correlated trigrams:
#        . price yesterday whim
#        . gold owns mines
#        . reported yesterday cra
# # 'rape-oil':
#   . Most correlated unigrams:
#        . whim
#        . sequestered
#        . miguel
#   . Most correlated bigrams:
#        . sequestered shares
#        . nippon steel
#        . san miguel
#   . Most correlated trigrams:
#        . standard bell chairman
#        . quoted nippon steel
#        . san miguel corp
# # 'rapeseed':
#   . Most correlated unigrams:
#        . conrac
#        . rumor
#        . madeira
#   . Most correlated bigrams:
#        . textile calls
#        . calls report
#        . dominion textile
#   . Most correlated trigrams:
#        . textile calls report
#        . report bid burlington
#        . calls report bid
# # 'reserves':
#   . Most correlated unigrams:
#        . purolator
#        . lvi
#        . lbo
#   . Most correlated bigrams:
#        . data access
#        . purolator courier
#        . hutton lbo
#   . Most correlated trigrams:
#        . hutton lbo said
#        . lbo said tender
#        . merger agreement purolator
# # 'retail':
#   . Most correlated unigrams:
#        . paxar
#        . conrac
#        . rumor
#   . Most correlated bigrams:
#        . calls report
#        . textile calls
#        . dominion textile
#   . Most correlated trigrams:
#        . report bid burlington
#        . dominion textile calls
#        . calls report bid
# # 'rice':
#   . Most correlated unigrams:
#        . spirits
#        . textile
#        . datron
#   . Most correlated bigrams:
#        . 545 mln
#        . trump interstate
#        . american brands
#   . Most correlated trigrams:
#        . sell spirits unit
#        . trump interstate properties
#        . 545 mln dlrs
# # 'rubber':
#   . Most correlated unigrams:
#        . alexanders
#        . textile
#        . datron
#   . Most correlated bigrams:
#        . interstate properties
#        . sell spirits
#        . trump interstate
#   . Most correlated trigrams:
#        . sell spirits unit
#        . dlrs american brands
#        . trump interstate properties
# # 'rye':
#   . Most correlated unigrams:
#        . komatsu
#        . sumitomo
#        . atlas
#   . Most correlated bigrams:
#        . securities business
#        . komatsu said
#        . atlas said
#   . Most correlated trigrams:
#        . said development pre
#        . atlas statement said
#        . 976 38 mln
# # 'ship':
#   . Most correlated unigrams:
#        . borden
#        . interco
#        . uccel
#   . Most correlated bigrams:
#        . computer associates
#        . hicks haas
#        . society savings
#   . Most correlated trigrams:
#        . 85 66 pct
#        . 37 dlrs share
#        . hicks haas group
# # 'silver':
#   . Most correlated unigrams:
#        . conrac
#        . rumor
#        . madeira
#   . Most correlated bigrams:
#        . properties talks
#        . dominion textile
#        . acquire alexanders
#   . Most correlated trigrams:
#        . talks acquire alexanders
#        . interstate properties talks
#        . properties talks acquire
# # 'sorghum':
#   . Most correlated unigrams:
#        . interstate
#        . alexanders
#        . textile
#   . Most correlated bigrams:
#        . acquire alexanders
#        . interstate properties
#        . trump interstate
#   . Most correlated trigrams:
#        . talks acquire alexanders
#        . properties talks acquire
#        . trump interstate properties
# # 'soy-meal':
#   . Most correlated unigrams:
#        . ccl
#        . conrac
#        . rumor
#   . Most correlated bigrams:
#        . textile calls
#        . calls report
#        . dominion textile
#   . Most correlated trigrams:
#        . report bid burlington
#        . bid burlington rumor
#        . dominion textile calls
# # 'soy-oil':
#   . Most correlated unigrams:
#        . paxar
#        . conrac
#        . rumor
#   . Most correlated bigrams:
#        . calls report
#        . textile calls
#        . dominion textile
#   . Most correlated trigrams:
#        . report bid burlington
#        . dominion textile calls
#        . calls report bid
# # 'soybean':
#   . Most correlated unigrams:
#        . clevite
#        . cadillac
#        . fairview
#   . Most correlated bigrams:
#        . fairview says
#        . says received
#        . cadillac fairview
#   . Most correlated trigrams:
#        . received acquisition proposals
#        . cadillac fairview says
#        . fairview says received
# # 'strategic-metal':
#   . Most correlated unigrams:
#        . conrac
#        . rumor
#        . madeira
#   . Most correlated bigrams:
#        . textile calls
#        . calls report
#        . dominion textile
#   . Most correlated trigrams:
#        . textile calls report
#        . report bid burlington
#        . calls report bid
# # 'sugar':
#   . Most correlated unigrams:
#        . fairview
#        . ecusta
#        . glatfelter
#   . Most correlated bigrams:
#        . blue arrow
#        . says received
#        . cadillac fairview
#   . Most correlated trigrams:
#        . fairview says received
#        . ecusta corp 149
#        . 20 10 dlrs
# # 'sun-meal':
#   . Most correlated unigrams:
#        . komatsu
#        . sumitomo
#        . atlas
#   . Most correlated bigrams:
#        . securities business
#        . komatsu said
#        . atlas said
#   . Most correlated trigrams:
#        . said development pre
#        . atlas statement said
#        . 976 38 mln
# # 'sun-oil':
#   . Most correlated unigrams:
#        . forrest
#        . monier
#        . whim
#   . Most correlated bigrams:
#        . bell group
#        . whim creek
#        . nippon steel
#   . Most correlated trigrams:
#        . acquiring shares sentence
#        . brokers warburg securities
#        . quoted nippon steel
# # 'sunseed':
#   . Most correlated unigrams:
#        . bashaw
#        . paxar
#        . conrac
#   . Most correlated bigrams:
#        . entered talks
#        . acquisition parties
#        . conrac corp
#   . Most correlated trigrams:
#        . said entered talks
#        . talks acquisition parties
#        . entered talks acquisition
# # 'tea':
#   . Most correlated unigrams:
#        . bell
#        . auxton
#        . conrac
#   . Most correlated bigrams:
#        . entered talks
#        . acquisition parties
#        . conrac corp
#   . Most correlated trigrams:
#        . said entered talks
#        . talks acquisition parties
#        . entered talks acquisition
# # 'tin':
#   . Most correlated unigrams:
#        . madeira
#        . interstate
#        . alexanders
#   . Most correlated bigrams:
#        . acquire alexanders
#        . interstate properties
#        . trump interstate
#   . Most correlated trigrams:
#        . interstate properties talks
#        . properties talks acquire
#        . trump interstate properties
# # 'trade':
#   . Most correlated unigrams:
#        . electrospace
#        . tonnes
#        . gillette
#   . Most correlated bigrams:
#        . electrospace systems
#        . continental materials
#        . 000 tonnes
#   . Most correlated trigrams:
#        . sell rko pictures
#        . agreement sell rko
#        . gencorp said agreement
# # 'veg-oil':
#   . Most correlated unigrams:
#        . clevite
#        . cadillac
#        . fairview
#   . Most correlated bigrams:
#        . fairview says
#        . says received
#        . cadillac fairview
#   . Most correlated trigrams:
#        . received acquisition proposals
#        . cadillac fairview says
#        . fairview says received
# # 'wheat':
#   . Most correlated unigrams:
#        . borden
#        . uccel
#        . interco
#   . Most correlated bigrams:
#        . computer associates
#        . hicks haas
#        . society savings
#   . Most correlated trigrams:
#        . 85 66 pct
#        . 37 dlrs share
#        . hicks haas group
# # 'wpi':
#   . Most correlated unigrams:
#        . conrac
#        . rumor
#        . madeira
#   . Most correlated bigrams:
#        . properties talks
#        . dominion textile
#        . acquire alexanders
#   . Most correlated trigrams:
#        . talks acquire alexanders
#        . interstate properties talks
#        . properties talks acquire
# # 'yen':
#   . Most correlated unigrams:
#        . spirits
#        . textile
#        . datron
#   . Most correlated bigrams:
#        . 545 mln
#        . trump interstate
#        . american brands
#   . Most correlated trigrams:
#        . sell spirits unit
#        . trump interstate properties
#        . 545 mln dlrs

# %%
#reference:https://colab.research.google.com/drive/1JW2I6cU_ypfRXfIfqMPQwMEA6LzGav-Y#scrollTo=kRviyvPXec-K
